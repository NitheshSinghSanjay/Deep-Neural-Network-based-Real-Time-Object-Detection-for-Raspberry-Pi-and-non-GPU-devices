# %%
from gluoncv import data, utils
from matplotlib import pyplot as plt

# %%
train_dataset = data.COCODetection(splits=['instances_train2017'])
val_dataset = data.COCODetection(splits=['instances_val2017'])
print('Number of training images:', len(train_dataset))
print('Number of validation images:', len(val_dataset))
# Out:
# loading annotations into memory...
# Done (t=21.19s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.72s)
# creating index...
# index created!
# Number of training images: 117266
# Number of validation images: 4952

# %%
train_image, train_label = train_dataset[100002]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)
# Out:
# Image size (height, width, RGB): (500, 400, 3)
# Num of objects: 5
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[ 76.66 179.92  89.55 204.88]
#  [ 65.17 279.78 103.49 302.37]
#  [102.53 263.86 150.04 311.38]
#  [149.23 238.98 399.   330.11]
#  [  9.07 174.02  21.05 199.73]]
# Class IDs (num_boxes, ):
#  [[9.]
#  [2.]
#  [7.]
#  [7.]
#  [9.]]

# %%
utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
